# %%
from math import *
from sympy import *
from tkinter import *
from tkinter import ttk
from statistics import mean, median
from matplotlib.pyplot import plot

# %% [raw]
# Test project of a Calculator capable of performing simple as well as scientific calculations (function integrals and derivatives included) in Python.
#
# The goal was to learn the usage of tkinter Python library for GUI, which is not taught on most python courses.

# %%
expression = "0"
x, y, z, t = symbols('x y z t')

# %%
def press(num):
    global expression
    expression = expression + str(num)
    equation.set(expression)

def clear():
    global expression
    expression = ""
    equation.set("")
    
def backspace():
    global expression
    powerReplacement(expression)
    expression = expression[:-1]
    equation.set(expression)

def calculate():
    try:
        global expression
        total = str(eval(expression))
        equation.set(total)
        expression = ""
    except:
        equation.set(" error ")
        expression = ""
        
if __name__ == "__main__":
    gui=Tk()
    gui.title("Simple Calculator")
    gui.geometry("600x400")
    gui.minsize(600, 400) # set minimum window size value
    gui.maxsize(600, 400) # set maximum window size value
    equation = StringVar()
    expression_field = Entry(gui, font=('Arial',16), textvariable=equation, width = 30)
    expression_field.pack(padx = 5, pady = 5)
    expression_field.grid(columnspan=10, ipadx=100, ipady=10)
    equation.set(expression)

    # It's best to start from 2 rows beneath the main line
    
buttonNum1 = Button(gui, text=' 1 ',font=('Arial',12), command = lambda: press(1),height=1, width=5)
buttonNum1.grid(row=1, column=0)
buttonNum4 = Button(gui, text=' 4 ',font=('Arial',12), command = lambda: press(4),height=1, width=5)
buttonNum4.grid(row=2, column=0)
buttonNum7 = Button(gui, text=' 7 ',font=('Arial',12), command = lambda: press(7),height=1, width=5)
buttonNum7.grid(row=3, column=0)
buttonNum0 = Button(gui, text=' 0 ',font=('Arial',12), command = lambda: press(0),height=1, width=5)
buttonNum0.grid(row=4, column=0)

buttonPow = Button(gui, text='Pow',font=('Arial',12), command = lambda: press("**"),height=1, width=5)
buttonPow.grid(row=5, column=0)
buttonZ = Button(gui, text=' e ',font=('Arial',12), command = lambda: press("e"),height=1, width=5)
buttonZ.grid(row=6, column=0)
buttonPi = Button(gui, text='Pi',font=('Arial',12), command = lambda: press("pi"),height=1, width=5)
buttonPi.grid(row=7, column=0)
buttonX = Button(gui, text=' x(var) ',font=('Arial',12), command = lambda: press("x"),height=1, width=5)
buttonX.grid(row=8, column=0)

buttonNum2 = Button(gui, text=' 2 ',font=('Arial',12), command = lambda: press(2),height=1, width=5)
buttonNum2.grid(row=1, column=1)
buttonNum5 = Button(gui, text=' 5 ',font=('Arial',12), command = lambda: press(5),height=1, width=5)
buttonNum5.grid(row=2, column=1)
buttonNum8 = Button(gui, text=' 8 ',font=('Arial',12), command = lambda: press(8),height=1, width=5)
buttonNum8.grid(row=3, column=1)
buttonEqual = Button(gui, text=' = ',font=('Arial',12), command = lambda: press("="),height=1, width=5)
buttonEqual.grid(row=4, column=1)

buttonModulus = Button(gui, text='Mod%',font=('Arial',12), command = lambda: press("%"),height=1, width=5)
buttonModulus.grid(row=5, column=1)
buttonInfinite = Button(gui, text=' inf ',font=('Arial',12), command = lambda: press("oo"),height=1, width=5)
buttonInfinite.grid(row=6, column=1)
buttonComma = Button(gui, text=' , ',font=('Arial',12), command = lambda: press(","),height=1, width=5)
buttonComma.grid(row=7, column=1)
buttonY = Button(gui, text=' y(var) ',font=('Arial',12), command = lambda: press("y"),height=1, width=5)
buttonY.grid(row=8, column=1)


buttonNum3 = Button(gui, text=' 3 ',font=('Arial',12), command = lambda: press(3),height=1, width=5)
buttonNum3.grid(row=1, column=2)
buttonNum6 = Button(gui, text=' 6 ',font=('Arial',12), command = lambda: press(6),height=1, width=5)
buttonNum6.grid(row=2, column=2)
buttonNum9 = Button(gui, text=' 9 ',font=('Arial',12), command = lambda: press(9),height=1, width=5)
buttonNum9.grid(row=3, column=2)
buttonDec = Button(gui, text=' . ',font=('Arial',12), command = lambda: press("."),height=1, width=5)
buttonDec.grid(row=4, column=2)

buttonFDiv = Button(gui, text='FDiv',font=('Arial',12), command = lambda: press("//"),height=1, width=5)
buttonFDiv.grid(row=5, column=2)
buttonPar21 = Button(gui, text=' [ ',font=('Arial',12), command = lambda: press("["),height=1, width=5)
buttonPar21.grid(row=6, column=2)
buttonPar11 = Button(gui, text=' ( ',font=('Arial',12), command = lambda: press("("),height=1, width=5)
buttonPar11.grid(row=7, column=2)
buttonZ = Button(gui, text=' z(var) ',font=('Arial',12), command = lambda: press("z"),height=1, width=5)
buttonZ.grid(row=8, column=2)


buttonPlus = Button(gui, text=' + ',font=('Arial',12), command = lambda: press("+"),height=1, width=5)
buttonPlus.grid(row=1, column=3)
buttonMinus = Button(gui, text=' - ',font=('Arial',12), command = lambda: press("-"),height=1, width=5)
buttonMinus.grid(row=2, column=3)
buttonProd = Button(gui, text=' * ',font=('Arial',12), command = lambda: press("*"),height=1, width=5)
buttonProd.grid(row=3, column=3)
buttonDiv = Button(gui, text=' / ',font=('Arial',12), command = lambda: press("/"),height=1, width=5)
buttonDiv.grid(row=4, column=3)

buttonAvg = Button(gui, text=' Avg ',font=('Arial',12), command = lambda: press("mean(["),height=1, width=5)
buttonAvg.grid(row=5, column=3)
buttonPar22 = Button(gui, text=' ] ',font=('Arial',12), command = lambda: press("]"),height=1, width=5)
buttonPar22.grid(row=6, column=3)
buttonPar12 = Button(gui, text=' ) ',font=('Arial',12), command = lambda: press(")"),height=1, width=5)
buttonPar12.grid(row=7, column=3)
buttonT = Button(gui, text=' t(var) ',font=('Arial',12), command = lambda: press("t"),height=1, width=5)
buttonT.grid(row=8, column=3)

buttonSin = Button(gui, text='Sin',font=('Arial',12), command = lambda: press("sin("),height=1, width=5)
buttonSin.grid(row=1, column=4)
buttonCos = Button(gui, text='Cos',font=('Arial',12), command = lambda: press("cos("),height=1, width=5)
buttonCos.grid(row=2, column=4)
buttonTan = Button(gui, text='Tan',font=('Arial',12), command = lambda: press("tan("),height=1, width=5)
buttonTan.grid(row=3, column=4)
buttonSinh = Button(gui, text='Sinh ',font=('Arial',12), command = lambda: press("sinh("),height=1, width=5)
buttonSinh.grid(row=4, column=4)
buttonCosh = Button(gui, text='Cosh',font=('Arial',12), command = lambda: press("cosh("),height=1, width=5)
buttonCosh.grid(row=5, column=4)
buttonTanh = Button(gui, text='Tanh',font=('Arial',12), command = lambda: press("tanh("),height=1, width=5)
buttonTanh.grid(row=6, column=4)
buttonLn = Button(gui, text='ln',font=('Arial',12), command = lambda: press("log("),height=1, width=5)
buttonLn.grid(row=7, column=4)
buttonLog = Button(gui, text='Log',font=('Arial',12), command = lambda: press("log10("),height=1, width=5)
buttonLog.grid(row=8, column=4)

buttonIntegral = Button(gui, text='Integral',font=('Arial',12), command = lambda: press("integrate("),height=1, width=7)
buttonIntegral.grid(row=1, column=5)
buttonDerivate = Button(gui, text='d/dx',font=('Arial',12), command = lambda: press("diff("),height=1, width=7)
buttonDerivate.grid(row=2, column=5)
buttonLimit = Button(gui, text='lim',font=('Arial',12), command = lambda: press("limit("),height=1, width=7)
buttonLimit.grid(row=3, column=5)
buttonMedian = Button(gui, text=' Median ',font=('Arial',12), command = lambda: press("median(["),height=1, width=7)
buttonMedian.grid(row=4, column=5)

buttonIntegral = Button(gui, text='|nr|',font=('Arial',12), command = lambda: press("fabs("),height=1, width=7)
buttonIntegral.grid(row=5, column=5)
buttonDerivate = Button(gui, text='n!',font=('Arial',12), command = lambda: press("factorial("),height=1, width=7)
buttonDerivate.grid(row=6, column=5)

buttonLimit = Button(gui, text='lim',font=('Arial',12), command = lambda: press("limit("),height=1, width=7)
buttonLimit.grid(row=7, column=5)
buttonMedian = Button(gui, text=' Median ',font=('Arial',12), command = lambda: press("median(["),height=1, width=7)
buttonMedian.grid(row=8, column=5)

buttonASin = Button(gui, text='Arc Sin',font=('Arial',12), command = lambda: press("asin("),height=1, width=10)
buttonASin.grid(row=1, column=6)
buttonACos = Button(gui, text='Arc Cos',font=('Arial',12), command = lambda: press("acos("),height=1, width=10)
buttonACos.grid(row=2, column=6)
buttonATan = Button(gui, text='Arc Tan',font=('Arial',12), command = lambda: press("atan("),height=1, width=10)
buttonATan.grid(row=3, column=6)

buttonASinh = Button(gui, text='Arc Sinh',font=('Arial',12), command = lambda: press("asinh("),height=1, width=10)
buttonASinh.grid(row=4, column=6)
buttonACosh = Button(gui, text='Arc Cosh',font=('Arial',12), command = lambda: press("acosh("),height=1, width=10)
buttonACosh.grid(row=5, column=6)
buttonATanh = Button(gui, text='Arc Tanh',font=('Arial',12), command = lambda: press("atanh("),height=1, width=10)
buttonATanh.grid(row=6, column=6)

buttonDeg = Button(gui, text='Rad->Deg',font=('Arial',12), bg='cyan', command = lambda: press("degrees("),height=1, width=10)
buttonDeg.grid(row=7, column=6)
buttonRad = Button(gui, text='Deg->Rad',font=('Arial',12), bg='cyan', command = lambda: press("radians("),height=1, width=10)
buttonRad.grid(row=8, column=6)

buttonCalc = Button(gui, text='Calculate',font=('Arial',12), bg='green', fg='white', command = calculate,height=1, width=10)
buttonCalc.grid(row=1, column=7)
buttonClear = Button(gui, text=' Backspace ',font=('Arial',12), bg='orange', fg='white', command = backspace, height=1, width=10)
buttonClear.grid(row=2, column=7)
buttonClear = Button(gui, text=' Clear ',font=('Arial',12), bg='red', fg='white', command = clear, height=1, width=10)
buttonClear.grid(row=3, column=7)


gui.mainloop()
